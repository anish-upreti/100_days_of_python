# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd

# %% [markdown]
# **Importing dataset**

# %%
dataset = pd.read_csv("salaries_by_college_major.csv")

# %% [markdown]
# **Some code cells to see number of columns and rows, some part of our dataframe, name of our columns....**

# %%
dataset.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
dataset.shape
# Out:
# (51, 6)

# %% [markdown]
# **Checking for missing data,junk data and data cleaning**

# %%
dataset.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
dataset.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_dataset = dataset.dropna()

# %%
clean_dataset.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %% [markdown]
# **To select a  particular column and check for highest value, get index, retrieve data**

# %%
clean_dataset["Mid-Career Median Salary"]
# Out:
# 0      77100.0
# 1     101000.0
# 2      71900.0
# 3      61500.0
# 4      76800.0
# 5      64900.0
# 6      64800.0
# 7      72100.0
# 8     107000.0
# 9      79900.0
# 10     90500.0
# 11     70000.0
# 12    105000.0
# 13     95500.0
# 14     88900.0
# 15     56300.0
# 16     56900.0
# 17     98600.0
# 18     52000.0
# 19    103000.0
# 20     64700.0
# 21     68500.0
# 22     88300.0
# 23     62600.0
# 24     65500.0
# 25     79500.0
# 26     59800.0
# 27     60600.0
# 28     71000.0
# 29     57500.0
# 30     94700.0
# 31     74800.0
# 32     53200.0
# 33     80900.0
# 34     66700.0
# 35     82300.0
# 36     79600.0
# 37     92400.0
# 38     93600.0
# 39     55000.0
# 40     67000.0
# 41     55300.0
# 42     81200.0
# 43     91700.0
# 44     97300.0
# 45     78200.0
# 46     60400.0
# 47     52000.0
# 48     58200.0
# 49     53100.0
# Name: Mid-Career Median Salary, dtype: float64

# %%
clean_dataset["Mid-Career Median Salary"].max()
# Out:
# 107000.0

# %%
clean_dataset["Mid-Career Median Salary"].idxmax()
# Out:
# 8

# %%
clean_dataset['Undergraduate Major'].loc[8]
# Out:
# 'Chemical Engineering'

# %% [markdown]
# **To find the highest and lowest starting salary and degrees**

# %%
clean_dataset["Starting Median Salary"].max()
# Out:
# 74300.0

# %%
clean_dataset["Starting Median Salary"].idxmax()
# Out:
# 43

# %%
clean_dataset['Undergraduate Major'].loc[43]
# Out:
# 'Physician Assistant'

# %%
clean_dataset["Starting Median Salary"].min()
# Out:
# 34000.0

# %%
clean_dataset["Starting Median Salary"].idxmin()
# Out:
# 49

# %%
clean_dataset['Undergraduate Major'].loc[49]
# Out:
# 'Spanish'

# %% [markdown]
# **For difference of columns**

# %%
diff = clean_dataset['Mid-Career 90th Percentile Salary'] - clean_dataset['Mid-Career 10th Percentile Salary']

# %%
clean_dataset.insert(1, "difference", diff)

# %%
clean_dataset.head()
# Out:
#      Undergraduate Major  difference  Starting Median Salary  \
# 0             Accounting    109800.0                 46000.0
# 1  Aerospace Engineering     96700.0                 57700.0
# 2            Agriculture    113700.0                 42600.0
# 3           Anthropology    104200.0                 36800.0
# 4           Architecture     85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# ...

# %% [markdown]
# **To sort out the values in ascending and descending order**

# %%
clean_dataset.sort_values("difference")
# Out:
#                      Undergraduate Major  difference  Starting Median Salary  \
# 40                               Nursing     50700.0                 54200.0
# 43                   Physician Assistant     57600.0                 74300.0
# 41                             Nutrition     65300.0                 39900.0
# 49                               Spanish     65400.0                 34000.0
# 27            Health Care Administration     66400.0                 38800.0
# 47                              Religion     66700.0                 34100.0
# 23                              Forestry     70000.0                 39100.0
# 32                       Interior Design     71300.0                 36100.0
# 18                             Education     72700.0                 34900.0
# 15                      Criminal Justice     74800.0                 35000.0
# 26                        Graphic Design     76000.0                 35700.0
# ...

# %%
clean_dataset.sort_values("difference", ascending = False)
# Out:
#                      Undergraduate Major  difference  Starting Median Salary  \
# 17                             Economics    159400.0                 50100.0
# 22                               Finance    147800.0                 47900.0
# 37                                  Math    137800.0                 45400.0
# 36                             Marketing    132900.0                 40800.0
# 42                            Philosophy    132500.0                 39900.0
# 45                     Political Science    126800.0                 40800.0
# 8                   Chemical Engineering    122100.0                 63200.0
# 44                               Physics    122000.0                 50300.0
# 33               International Relations    118800.0                 40900.0
# 16                                 Drama    116300.0                 35900.0
# 30                Industrial Engineering    115900.0                 57700.0
# ...

# %% [markdown]
# **Grouping and Pivoting Data with Pandas**

# %%
clean_dataset.groupby('Group').count()
# Out:
#           Undergraduate Major  difference  Starting Median Salary  \
# Group
# Business                   12          12                      12
# HASS                       22          22                      22
# STEM                       16          16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary
# Group
# Business                                 12
# HASS                                     22
# STEM                                     16
